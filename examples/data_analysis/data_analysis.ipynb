# %%
from howtrader.trader.constant import Exchange,Interval
from data_analysis import DataAnalysis
from datetime import datetime
import matplotlib.pyplot as plt

# %%
herramiento = DataAnalysis()
herramiento.load_history(    
    symbol="BTCUSDT", 
    exchange=Exchange.OKX, 
    interval=Interval.MINUTE, 
    start=datetime(2024, 10, 3), 
    end=datetime(2024, 10, 4),
    rate = 8/10000,
    index_3to1 = ["ATR","CCI"],
    index_1to1 = ["STDDEV","SMA"],
    index_2to2 = ["AROON"],
    index_2to1 = ["AROONOSC"],
    index_4to1 = ["BOP"],
    window_index=30,
)
# Out:
# 2024-10-04 17:40:26.256716	开始加载历史数据
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 herramiento = DataAnalysis()
# ----> 2 herramiento.load_history(
#       3     symbol="BTCUSDT",
#       4     exchange=Exchange.OKX,
#       5     interval=Interval.MINUTE,
#       6     start=datetime(2024, 10, 3),
#       7     end=datetime(2024, 10, 4),
#       8     rate = 8/10000,
#       9     index_3to1 = ["ATR","CCI"],
#      10     index_1to1 = ["STDDEV","SMA"],
#      11     index_2to2 = ["AROON"],
#      12     index_2to1 = ["AROONOSC"],
#      13     index_4to1 = ["BOP"],
#      14     window_index=30,
#      15 )
#
# File D:\howtrader\examples\data_analysis\data_analysis.py:73, in DataAnalysis.load_history(self, symbol, exchange, interval, start, end, rate, index_1to1, index_2to2, index_3to1, index_2to1, index_4to1, window_index, window_volatility)
#      70 self.index_4to1 = index_4to1
#      72 # Load history data from database
# ---> 73 bars = database.load_bar_data(
#      74     symbol=symbol,
#      75     exchange=exchange,
#      76     interval=interval,
#      77     start=start,
#      78     end=end,
#      79
#      80 )
#      82 output(f"历史数据加载完成，数据量：{len(bars)}")
#      84 # Generate history data in DataFrame
#
# AttributeError: 'NoneType' object has no attribute 'load_bar_data'

# %%
data = herramiento.base_analysis()

# %%
herramiento.show_chart(data[:1500], boll_wide=2.8)

# %%
# 多时间周期分析
intervals = ["5min","15min","30min","1h","2h","4h"]
herramiento.multi_time_frame_analysis(intervals=intervals)
# Out:
# 2024-10-04 17:40:42.730436	------------------------------------------------
# 2024-10-04 17:40:42.730436	合成5min周期K先并开始数据分析
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 # 多时间周期分析
#       2 intervals = ["5min","15min","30min","1h","2h","4h"]
# ----> 3 herramiento.multi_time_frame_analysis(intervals=intervals)
#
# File D:\howtrader\examples\data_analysis\data_analysis.py:253, in DataAnalysis.multi_time_frame_analysis(self, intervals, df)
#     250 output(f"合成{interval}周期K先并开始数据分析")
#     252 data = pd.DataFrame()
# --> 253 data["open"] = df["open"].resample(interval, how="first")
#     254 data["high"] = df["high"].resample(interval, how="max")
#     255 data["low"] = df["low"].resample(interval, how="min")
#
# File ~\anaconda3\envs\okex\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\envs\okex\lib\site-packages\pandas\core\indexes\range.py:349, in RangeIndex.get_loc(self, key)
#     347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
# --> 349     raise KeyError(key)
#     350 self._check_indexing_error(key)
#     351 raise KeyError(key)
#
# KeyError: 'open'

# %%
import numpy as np

fcts =np.load(f'D:/howtrader/examples/factor/OLS_BNBUSDT_1H_0_fcts.npy',allow_pickle=True)
fcts
# Out:
# array(['TA_HT_DCPERIOD(ta_dx_14(ta_beta_10(ta_dx_14(high, low, close), ret), ts_kurt_20(ret), TA_OBV(close, volume)))',
#        'TA_OBV(TA_OBV(ts_kurt_20(ret), ts_kurt_20(ret)), ts_sum_8(R_up))',
#        'TA_OBV(TS_COV_20(TS_CORR_20(ta_dx_14(high, low, close), ret), TS_CORR_20(ta_dx_14(high, low, close), ret)), TS_CORR_20(ta_dx_14(high, low, close), ret))',
#        'TA_OBV(ts_sum_8(ret), diff(ta_lr_angle_5(volume)))',
#        'TS_CORR_20(TA_OBV(close, volume), diff(TA_OBV(close, volume)))',
#        'TS_CORR_20(diff(TS_CORR_20(ta_dx_14(high, low, close), ret)), ts_std_20(ta_lr_slope_5(close)))',
#        'TS_CORR_20(neg(TS_CORR_20(ta_dx_14(high, low, close), diff(volume))), macd(ts_range_5(ret)))',
#        'TS_CORR_20(ta_beta_10(TA_OBV(close, volume), ts_sum_8(ret)), ta_beta_10(ta_dx_14(high, low, close), ret))',
#        'TS_CORR_20(ta_mfi_14(TS_CORR_20(ta_mfi_14(high, low, close, volume), diff(volume)), TS_CORR_20(ta_mfi_14(high, low, close, volume), ret), ta_minus_di_14(high, low, close), ta_dx_14(high, low, close)), macd(ta_rsi_6(volume)))',
#        'TS_CORR_20(ts_skew_20(ta_mfi_14(high, low, close, volume)), TA_HT_TRENDLINE(ts_std_20(ret)))',
#        'TS_COV_20(TA_HT_DCPERIOD(ta_beta_10(ta_dx_14(high, low, close), ret)), ts_skew_20(ta_beta_10(ta_dx_14(high, low, close), ret)))',
#        'TS_COV_20(TA_HT_TRENDLINE(TS_CORR_20(ta_dx_14(high, low, close), ret)), ts_skew_20(ta_ema_8(volume)))',
#        'TS_COV_20(ret, ta_adx_14(ta_cmo_14(close), ts_skew_20(diff(volume)), ta_beta_10(ta_dx_14(high, low, close), ret)))',
#        'TS_COV_20(ta_minus_di_14(R_range, TS_COV_20(ta_dx_14(high, low, close), ret), ta_cci_14(high, low, close)), ta_rsi_6(volume))',
#        'TS_COV_20(ta_minus_di_14(high, low, close), macd(ts_range_5(volume)))',
#        'TS_COV_20(ts_range_5(ret), TS_COV_20(ts_argrange_5(volume), ta_cci_14(high, low, close)))',
#        'ht_sine(ta_mfi_14(ts_std_20(diff(volume)), ts_range_5(volume), TS_COV_20(ta_mfi_14(high, low, close, volume), ret), ta_aroonosc_14(high, low)))',
#        'mul(ta_lr_slope_5(ts_range_5(ret)), ta_lr_angle_5(ta_cmo_14(close)))',
#        'sub(TS_COV_20(ts_range_5(ret), ts_std_20(ret)), ts_std_20(ret))',
#        'ta_adx_14(TS_CORR_20(TS_CORR_20(ta_mfi_14(high, low, close, volume), diff(volume)), ta_lr_slope_5(volume)), ta_mfi_14(ta_tsf_5(close), ta_rsi_6(volume), ta_adx_14(high, low, close), ts_kurt_20(ret)), ta_lr_slope_5(volume))',
#        'ta_adx_14(TS_CORR_20(ta_dx_14(high, low, close), diff(volume)), ts_argrange_5(ts_std_20(diff(volume))), TS_COV_20(ts_skew_20(ret), ta_beta_10(ta_mfi_14(high, low, close, volume), ret)))',
#        'ta_adx_14(ta_rsi_6(close), ts_argrange_5(ts_skew_20(ret)), TS_CORR_20(ts_skew_20(ret), ts_range_5(volume)))',
#        'ta_aroonosc_14(TS_CORR_20(ts_range_5(ret), TS_CORR_20(ta_dx_14(high, low, close), diff(volume))), macd(ta_lr_slope_5(close)))',
#        'ta_aroonosc_14(TS_COV_20(ta_rsi_6(close), ta_tsf_5(volume)), ts_sum_8(ts_sum_8(ret)))',
#        'ta_aroonosc_14(ht_sine(ta_ema_8(ret)), mul(R_dn, ts_argrange_5(volume)))',
#        'ta_aroonosc_14(ht_sine(ta_lr_angle_5(close)), ts_skew_20(ta_ema_8(ret)))',
#        'ta_aroonosc_14(ta_ema_8(ts_sum_8(ret)), ta_minus_di_14(ta_ema_8(volume), TS_CORR_20(ta_dx_14(high, low, close), ret), ta_ema_8(ret)))',
#        'ta_aroonosc_14(ta_rsi_6(volume), TS_COV_20(ts_sum_8(ret), ta_cmo_14(volume)))',
#        'ta_aroonosc_14(ts_sum_8(ta_aroonosc_14(high, low)), ta_aroonosc_14(ts_std_20(ret), TS_CORR_20(ta_mfi_14(high, low, close, volume), ret)))',
#        'ta_aroonosc_14(ts_sum_8(ta_mfi_14(high, low, close, volume)), ta_tsf_5(ta_minus_di_14(high, low, close)))',
#        'ta_cci_14(ht_sine(ta_cci_14(high, low, close)), ts_argrange_5(TS_CORR_20(ta_dx_14(high, low, close), ret)), diff(ta_rsi_6(close)))',
#        'ta_cci_14(ret, ht_sine(ta_minus_di_14(high, low, close)), ht_leadsine(ts_std_20(diff(volume))))',
#        'ta_cci_14(ta_adx_14(ta_dx_14(high, low, close), TS_CORR_20(ta_dx_14(high, low, close), ret), ta_rsi_6(close)), ta_dx_14(ta_cmo_14(volume), ts_skew_20(diff(volume)), ta_beta_10(ta_dx_14(high, low, close), ret)), ts_argrange_5(close))',
#        'ta_cci_14(ta_dx_14(ta_ema_8(volume), ta_minus_di_14(high, low, close), TS_COV_20(ta_dx_14(high, low, close), ret)), ta_rsi_6(ret), ta_minus_di_14(TS_CORR_20(ta_mfi_14(high, low, close, volume), diff(volume)), R_dn, TS_CORR_20(ta_dx_14(high, low, close), diff(volume))))',
#        'ta_cci_14(ta_ema_8(ta_mfi_14(high, low, close, volume)), ht_leadsine(ta_lr_angle_5(close)), ta_beta_10(ta_lr_angle_5(close), ts_kurt_20(ret)))',
#        'ta_cci_14(ta_minus_di_14(ta_tsf_5(volume), ta_aroonosc_14(high, low), ta_beta_10(ta_dx_14(high, low, close), diff(volume))), ts_sum_8(R_dn), TA_HT_TRENDLINE(TS_CORR_20(ta_dx_14(high, low, close), ret)))',
#        'ta_cci_14(ta_rsi_6(close), TA_HT_DCPERIOD(TS_COV_20(ta_dx_14(high, low, close), ret)), ta_minus_di_14(high, low, close))',
#        'ta_cci_14(ts_argrange_5(ta_beta_10(ta_mfi_14(high, low, close, volume), ret)), ts_argrange_5(ta_lr_angle_5(volume)), ta_lr_slope_5(close))',
#        'ta_cci_14(ts_kurt_20(R_dn), ht_leadsine(ta_rsi_6(close)), ht_sine(ta_aroonosc_14(high, low)))',
#        'ta_cci_14(ts_skew_20(diff(volume)), ts_skew_20(ta_minus_di_14(high, low, close)), ta_mfi_14(TS_COV_20(ta_mfi_14(high, low, close, volume), ret), R_up, ta_lr_angle_5(close), ts_range_5(ret)))',
#        'ta_dx_14(TS_COV_20(TS_COV_20(ta_dx_14(high, low, close), ret), ts_argrange_5(volume)), ts_std_20(ts_kurt_20(diff(volume))), ta_rsi_6(ta_lr_angle_5(volume)))',
#        'ta_dx_14(ht_leadsine(ta_aroonosc_14(high, low)), ta_dx_14(ts_sum_8(ret), ta_ema_8(ret), ts_std_20(ret)), ht_leadsine(TS_CORR_20(ta_mfi_14(high, low, close, volume), diff(volume))))',
#        'ta_dx_14(mul(ta_cmo_14(volume), ta_rsi_6(volume)), ts_std_20(ta_mfi_14(high, low, close, volume)), TS_CORR_20(ta_mfi_14(high, low, close, volume), diff(volume)))',
#        'ta_lr_slope_5(ta_beta_10(ts_std_20(ret), ta_minus_di_14(high, low, close)))',
#        'ta_mfi_14(ht_sine(ta_lr_angle_5(close)), neg(ts_skew_20(ret)), ts_std_20(ta_beta_10(ta_mfi_14(high, low, close, volume), ret)), ta_adx_14(ta_cci_14(high, low, close), ta_beta_10(ta_dx_14(high, low, close), diff(volume)), ts_kurt_20(ret)))',
#        'ta_mfi_14(ta_mfi_14(high, low, close, volume), ta_dx_14(high, low, close), ts_skew_20(ta_lr_slope_5(volume)), ta_rsi_6(ta_tsf_5(volume)))',
#        'ta_mfi_14(ta_minus_di_14(ts_std_20(ret), TS_CORR_20(ta_dx_14(high, low, close), diff(volume)), ta_adx_14(high, low, close)), ta_lr_angle_5(volume), ta_adx_14(high, low, close), ta_aroonosc_14(ta_lr_slope_5(close), TS_CORR_20(ta_dx_14(high, low, close), ret)))',
#        'ta_mfi_14(ts_sum_8(ret), ta_ema_8(ta_aroonosc_14(high, low)), ta_dx_14(ta_mfi_14(high, low, close, volume), ta_beta_10(ta_mfi_14(high, low, close, volume), diff(volume)), TS_CORR_20(ta_mfi_14(high, low, close, volume), ret)), ta_tsf_5(close))',
#        'ta_minus_di_14(ta_lr_slope_5(ta_beta_10(ta_mfi_14(high, low, close, volume), ret)), add(ta_mfi_14(high, low, close, volume), ta_cmo_14(volume)), ta_minus_di_14(ta_rsi_6(close), ts_kurt_20(ret), TS_COV_20(ta_dx_14(high, low, close), ret)))',
#        'ta_rsi_6(ta_mfi_14(TS_COV_20(ta_dx_14(high, low, close), ret), R_range, ta_cmo_14(volume), ta_aroonosc_14(high, low)))'],
#       dtype='<U269')
